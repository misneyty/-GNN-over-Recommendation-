# %% [markdown]
# # Experiment Demo
#
# Use this notebook for quick experiments before moving stable code into `src/`.

# %%
from pathlib import Path
import sys

ROOT = Path('..').resolve()
sys.path.append(str(ROOT))

from src.data import load_dataset
from src.train import train
from src.utils import set_seed

set_seed(0)
dataset = load_dataset(ROOT / 'data_file')
result = train(dataset, model_name='mf', epochs=1, batch_size=1024)
result.valid_metrics
