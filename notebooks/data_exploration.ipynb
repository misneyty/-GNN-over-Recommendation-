# %% [markdown]
# # Data Exploration
#
# Use this notebook to inspect edge counts, node degrees, and paper feature statistics.

# %%
from pathlib import Path
import sys

ROOT = Path('..').resolve()
sys.path.append(str(ROOT))

from src.data import load_dataset

dataset = load_dataset(ROOT / 'data_file')
dataset
